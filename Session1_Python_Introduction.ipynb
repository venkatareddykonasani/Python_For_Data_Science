# %% [markdown]
# <a href="https://colab.research.google.com/github/venkatareddykonasani/Python_For_Data_Science/blob/main/Session1_Python_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section 0:Introduction
# **Welcome to Python Bootcamp**

# %% [markdown]
# ## 0.1 Contents

# %%
# Quick link for the video link
# https://youtu.be/BXO70FHs9Yg 
from IPython.display import YouTubeVideo
YouTubeVideo('BXO70FHs9Yg', width=500, height=300)

# %% [markdown]
# ## 0.2 Python Versions

# %%
YouTubeVideo('ghxpXPp4Vmo', width=500, height=300)
# https://youtu.be/ghxpXPp4Vmo

# %% [markdown]
# ## 0.3 Installing Python

# %%
YouTubeVideo('wA5IV2zDN4M', width=500, height=300)
# https://youtu.be/wA5IV2zDN4M

# %% [markdown]
# # Section 1: Basic Commands

# %%
YouTubeVideo('dbfiEa4rw44', width=500, height=300)
# https://youtu.be/dbfiEa4rw44

# %% [markdown]
# ## 1.1 - Simple Operations

# %%
# Simple addition in Python using '+' operator
571+95

# %%
# printing the result using 'print' statement
print(571+95)

# %%
# Simple subtraction in Python using '-' operator
459-67

# %%
# Simple multiplication in Python using '*' operator
78*91

# %%
# Simple division in Python using '/' operator
100/5

# %% [markdown]
# ## 1.2 - Commenting a line

# %%
# Type '#' at the start of the line to mark it as comment
print(568+23)

# %% [markdown]
# ## 1.3 - Errors

# %%
# A variable need to be defined before using in a syntax, else it would lead to 'NameError'. 
# In below example, variable 'p' is not yet defined and statement will lead to an error.
574*p

# %%
# An operator need to be applied to the right type of values (operands) else it will lead to error.
# In below example, '+' operator is applied on a number (576) and a string (p) which is incorrect leading to TypeError.
576+'p'

# %% [markdown]
# ## 1.4 - Variable Assignment

# %%
YouTubeVideo('bFIr2FGn6tw', width=500, height=300)
# https://youtu.be/bFIr2FGn6tw

# %%
# A variable can be assigned a value using '=' operator
# In below example, variable 'income' has been assigned a value of '12000'

income = 12000
print(income)

# %%
# variable x is assigned number '20'
x=20
print(x)

# %%
# variable x is assigned a string value
x="march"
print(x)

# %%
# delete statement removes/deletes a variable from memory
# In below example, variable x is deleted
del(x)

# %%
# Below statement will throw an error
# variable 'x' is deleted in above line of code thus its no longer available for python interpreter leading to error
print(x)

# %%
# Defining variable x again and initializing with value 20
x=20

# %%
# Initializaing variable y with value 30
y=30

# %%
# variable z is assigned a derieved value (from the multiplication of variable x and variable y
z=x*y

# %%
# printing variable z
print(z)

# %%
# Initializing a new variable k and assigning value 50
k=50

# %%
# Reassigning variable z, as multiplication of variable x and variable k
z=x*k

# %% [markdown]
# ## 1.5 - Naming Convention
# Python follows certain rules for naming a variable

# %%
# Rule 1: variable name must start with a letter or an underscore else it will lead to Error
# In below statement, variable name is getting started with a number ('1') thus leading to SyntaxError
1x=20

# %%
# In the below statement, digit '1' is swapped with 'x' at the begining position thus resolving the error
x1=20

# %%
# Rule 2: A variable name can only contain alpha-numeric characters and underscores
# In below statement, variable name contains a decimal thus leading to SyntaxError
x.1=30

# %%
# In the below statement, decimal '.' is replaced with underscore '_' thus resolving the error
x_1=20

# %%
# Space (' ') is not supported in a variable name
# In the below statement, variable name contains a space ' ' (between x and 1) thus leading to error
x 1=20

# %%
# Below statement also contains unsupported character '$' in the variable name thus leading to the error
x$20

# %% [markdown]
# # Section 2: Type of Objects

# %%
YouTubeVideo('G9_KaHMDKnE', width=500, height=300)
# https://youtu.be/G9_KaHMDKnE

# %% [markdown]
# ## 2.1 - Numbers

# %%
age=30
income=1250.567

# %%
print(type(age))
print(type(income))

# %%
print("Age - datatype", type(age))
print("Income - datatype", type(income))

# %% [markdown]
# ## 2.2 - Strings

# %%
name="Sheldon"
print(name)

# %%
print(name[0])

# %%
print(name[1])

# %%
print(name[0:3])

# %%
print(name[3:6])

# %%
print(name[3:4])

# %%
message="Python 5 day course - Statinfer"
print(message)

# %%
print(message[0:4])

# %%
print(len(message))

# %%
print(message[24:31])

# %%
print(message[20:31])

# %%
First_name="Sheldon"
Last_name="Cooper"
Name= First_name + Last_name

# %%
print(Name) #10 Times??

# %%
print(Name)

# %%
Name= First_name +" "+ Last_name 
print(Name)

# %%
print(Name*10)

# %% [markdown]
# ## 2.3 - List

# %%
YouTubeVideo('0pfzpETQDi4', width=500, height=300)
# https://youtu.be/0pfzpETQDi4

# %%
cust=["Sheldon","leonard", "penny"]
Age=[30, 31, 27]

# %%
print(cust)

# %%
print(Age)

# %%
print(cust[0])

# %%
print(Age[1])

# %%
cust_1=["Amy", "Raj"]

# %%
Final_cust=cust + cust_1

# %%
print(Final_cust)

# %%
print(len(Final_cust))

# %%
Final_cust.append("Howard")

# %%
print(Final_cust)

# %%
Final_cust.remove("penny")

# %%
print(Final_cust)

# %%
Final_cust[3]="john"

# %%
print(Final_cust)

# %%
Final_cust.sort()

# %%
print(Final_cust)

# %%
Final_cust.index("john")

# %% [markdown]
# ## 2.4 - Dictionaries

# %%
YouTubeVideo('rzN-kX2t94U', width=500, height=300)
# https://youtu.be/rzN-kX2t94U

# %%
#Key - value pairs

city={0:"L.A", 9:"P.A", 7:"FL"}

# %%
type(city)

# %%
print(city)

# %%
city[1]

# %%
city[0]

# %%
city[9]

# %%
city[7]

# %%
city.keys()

# %%
city.values()

# %%
cust_profile={"C001":"David", "C002":"Bill", "C003":"Jim"}

# %%
cust_profile[0]

# %%
cust_profile[C001]

# %%
cust_profile["C001"]

# %%
cust_profile["C002"]

# %%
#Updating values
cust_profile["C002"]="Tom"

# %%
print(cust_profile)

# %%
#Updating Keys
#C001 ---> C009

#Delete + Add

del(cust_profile["C001"])

# %%
print(cust_profile)

# %%
cust_profile["C009"]="David"

# %%
print(cust_profile)

# %%
# "C008" ==> ??
"C008" in cust_profile

# %%
"C002" in cust_profile

# %% [markdown]
# # Section 3: Important packages

# %%
YouTubeVideo('WtKlxhCgzHQ', width=500, height=300)
# https://youtu.be/WtKlxhCgzHQ

# %%
log(10)

# %%
import math
math.log(10)

# %%
exp(5)

# %%
math.exp(5)

# %%
sqrt(256)

# %%
math.sqrt(256)

# %% [markdown]
# ## 3.1 - numpy

# %%
import numpy as np

income=np.array([9000, 8756, 10000, 12450, 10200, 8000])
print(income)

# %%
type(income)

# %%
len(income)

# %%
income[0]

# %%
income[0:4]

# %%
expenses=income*0.7

# %%
print(expenses)

# %%
savings=income-expenses

# %%
print(savings)

# %%
my_list1=[3,8,12]
my_list2=[1,5,6]

my_array1=np.array([3,8,12])
my_array2=np.array([1,5,6])

# %%
print(my_list1)

# %%
print(my_array1)

# %%
print(my_list1+my_list2)

# %%
print(my_array1+my_array2)

# %% [markdown]
# ## 3.2 - pandas

# %%
import pandas as pd
#bank_data=pd.read_csv("C:\\user\\datasets\\bank_market.csv")
bank_data=pd.read_csv("https://raw.githubusercontent.com/venkatareddykonasani/python_5days/master/Day1_Files/Datasets/bank_market.csv")

# %%
print(bank_data)

# %% [markdown]
# ## 3.3 - matplotlib

# %%
YouTubeVideo('5R9DShVyl6U', width=500, height=300)
# https://youtu.be/5R9DShVyl6U

# %%
import matplotlib as mp 
import numpy as np

X= np.random.normal(size=1000)
Y= np.random.normal(size=1000)

# %%
print(X)

# %%
mp.pyplot.scatter(X,Y)

# %% [markdown]
# ## 3.4 - scikit-learn

# %%
import sklearn
from sklearn.linear_model import LogisticRegression

# %%
Logistic_model=LogisticRegression()
Logistic_model.fit(bank_data[["age","balance"]], bank_data["y"])

# %%
print(Logistic_model.coef_)

# %%
print(Logistic_model.intercept_)

# %% [markdown]
# # Section 4: Conditions and Loops

# %%
YouTubeVideo('kLyfufYogeA', width=500, height=300)
# https://youtu.be/kLyfufYogeA

# %% [markdown]
# ## 4.1 - Conditional statements

# %%
# Writing a simple 'if' condition to check if variable 'age' is less than 50
# In below code, if condition is FALSE since variable 'age' is greater than 50 thus print statement inside if block will not be executed.
age=60

if age<50:
  print("Age is less than 50") # This print statement is inside if block, notice the indentation.

print("Done with if") # This print statement is outside if block.

# %%
# In below lines of code, variable age is reassigned value 40.
# Since age is now less than 50, if condition is TRUE this time and the inner print statement will get executed.
age=40

if age<50:
  print("Age is less than 50") # This print statement is inside if block, notice the indentation.

print("Done with if") # This print statement is outside if block.

# %%
# This time we are  including 'else' block in addition to 'if' condition, 'else' block gets executed when 'if' condition is FALSE
# Note: Between 'if' and 'else' blocks, only one of the blocks get executed. 
# In below lines of code, else statement will get executed as 'if' condition will be FALSE 
age=60

if age<50:
  print("Age is less than 50")
else:
  print("Age is NOT less than 50")

print("Done with if")

# %%
# This time, variable age is set to 40 and it meets the 'if' condition (age<50).
#Thus, if block will get executed and 'Age is less than 50' will be printed. 
age=40

if age<50:
  print("Age is less than 50") # This print statement is part of 'if' condition
else:
  print("Age is NOT less than 50") # This print statement is part of 'else' condition
  
  print("Done with if")

# %%
# In below lines of code, we are including 'elif' statements in addition to 'if' and 'else' statements
# Note: Only of the 'if', 'elif' and 'else' statements gets to execute.

# Here, marks is assigned value 86 whic is satisfied in Fourth conditional statement below
marks=86

if(marks<30): # First conditional statement of the example- if
  print("fail")
elif(marks<60): # Second conditional statement of the example- elif
  print("Second Class") 
elif(marks<80): # Third conditional statement of the example- elif
  print("First Class") 
elif(marks<100): # Fourth conditional statement of the example- elif
  print("Distinction") 
else: # Fifth conditional statement of the example- if
  print("Error in marks")

# %% [markdown]
# ## 4.2 - For loop

# %%
# Writing a simple 'For' loop using range function
# In below example, range is defined from 1 till 20, thus for loop will execute 19 times, starting from 1 and ending one less than 20.
# Note: syntax for range funtion : range(start, end-1)
for i in range(1,20):
  print("Number is", i)

# %%
# In below example, for loop is updating value of sumx in each iteration by adding i
# Note: In each oteration, sumx is assigned new value which is sum of old sumx and value of i

# In first iteration, sumx (on right side) is 0 and i is 1 (iteration 1), thus new value assigned to sumx (on left side) is 0+1 = 1.
# In second iteration, the sumx (on right side) is 1 and i is 2 (iteration 2), thus new value assigned to sumx (on left side) is 1+2 = 3. And son on ...

sumx=0

for i in range(1,10):
  sumx=sumx+i
  print("Cumulative sum is", sumx)

# %%
# Breaking the loop as per some condition.
# Continuing from the previous example, for loop is is cumulatively adding numbers to sumx. However, the range condition is different this time, 1 to 200 (actually 199 inclusive).
# In below example, a break statement is provided inside an if statement and once if condition is true (i.e. cumulative sum reaches above 100), the for loop is stopped.

sumx=0

for i in range(1,200):
  sumx=sumx+i
  if(sumx>100):
    break
  print("Cumulative sum is", sumx)

# %% [markdown]
# ## 4.3 - List Comprehension

# %%
# Creating a list - using square bracket []
# In below statement, we are creatign a list named sample_list with initial values 1,2,3,4,5.
sample_list = [1,2,3,4,5]

# %%
# Using range function to create a list sequence
# In below statement, a list is generated using range function with numbers from 1 to 19

[i for i in range(1,20)]

# %%
# Continuing from above example, assigning the list to a new variable 'result'
result=[i for i in range(1,20)]
print(result)

# %%
# Adding 'if' condition to keep only those numbers smaller than 15 
result=[i for i in range(1,20) if i<15]
print(result)

# %%
# Continuing from the above example, adding an additional condition to check is number is odd (remainder after division from 2 is zero) 
result=[i for i in range(1,20) if i<15 if i%2 == 1 ]
print(result)

# %% [markdown]
# # Conclusion

# %%
YouTubeVideo('R0e3KJkwd8E', width=500, height=300)
# https://youtu.be/R0e3KJkwd8E

# %% [markdown]
# # Useful Links and Details

# %% [markdown]
# ---
# ### Next Session Link
# [Session-2 : Data manipulations with Python](https://colab.research.google.com/drive/1Jq7k7f-vH0-zSafha4N09v9DqLgjVX_L?usp=sharing)

# %% [markdown]
# ---
# ### Previous Session Link
# [
# Course Introduction](https://youtu.be/v8WvvX5DZi0)

# %% [markdown]
# ### Our Full Course Details
# [Enrol Now](https://statinfer.com/course/machine-learning-with-python-course-in-india/)

# %%
YouTubeVideo('v8WvvX5DZi0', width=500, height=300)
# https://youtu.be/v8WvvX5DZi0

# %% [markdown]
# [Enrol Now](https://statinfer.com/course/machine-learning-with-python-course-in-india/)
