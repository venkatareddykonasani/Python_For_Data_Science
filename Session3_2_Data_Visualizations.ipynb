# %% [markdown]
# <a href="https://colab.research.google.com/github/venkatareddykonasani/Python_For_Data_Science/blob/main/Session3_2_Data_Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Session3- Part2: Data Visualizations

# %% [markdown]
# ## Table of Contents
#
#
#
# * Continuous variable distributions
# * Box Plots
# * Violin Plots
# * Histograms
# * Categorical Variables Summary
# * Bar Charts
# * Continuous vs Continuous
# * Scatter Plots
# * Continuous vs Categorical
# * Histogram overlay
# * Multiple category Box Plots
# * Violin plots
# * Categorical vs Categorical
# * Bar Charts
# * Cross tables
# * Pivot table visualization
# * Heatmaps

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('g2eKTBUE6K8', width=500, height=300)
# https://youtu.be/g2eKTBUE6K8

# %% [markdown]
# # Bank Marketing Data Importing

# %%
import pandas as pd
bank_data=pd.read_csv("https://raw.githubusercontent.com/venkatareddykonasani/python_5days/master/Day3_Files/Datasets/bank-full.csv")
print(bank_data.shape)
#https://archive.ics.uci.edu/ml/datasets/Bank+Marketing/

# %%
bank_data.head()

# %%
import pandas as pd
bank_data=pd.read_csv("https://raw.githubusercontent.com/venkatareddykonasani/python_5days/master/Day3_Files/Datasets/bank-full.csv",sep=';')
print(bank_data.shape)

# %%
bank_data.head()

# %%
bank_data.info()

# %% [markdown]
# # Continuous variable distributions

# %%
YouTubeVideo('CyZ2Be2XtNY', width=500, height=300)
# https://youtu.be/CyZ2Be2XtNY

# %% [markdown]
# ## Box Plots

# %%
import matplotlib.pyplot as plt 
plt.boxplot(bank_data["balance"])

# %%
import matplotlib.pyplot as plt 
plt.boxplot(bank_data["age"])

# %%
plt.boxplot(bank_data["age"], whis= 2)

# %% [markdown]
# ## Vilon Plots

# %%
import seaborn as sns
sns.violinplot(y=bank_data["balance"])

# %%
sns.violinplot(y=bank_data["age"])

# %% [markdown]
# ## Histograms

# %%
import seaborn as sns
sns.distplot(bank_data["age"])

# %%
import seaborn as sns
sns.distplot(bank_data["age"],kde=False)

# %%
import seaborn as sns
sns.distplot(bank_data["balance"])

# %%
numeric_cols=[col for col in bank_data.columns if bank_data[col].dtypes in ["int64","float64"]]
print(numeric_cols)

# %%
plt.figure()
for col in numeric_cols:
  sns.distplot(bank_data[col])
  plt.title([col + " Histogram"])
  plt.show()

# %% [markdown]
# # Rossmann Store Sales Data

# %%
YouTubeVideo('Kd4BGDpSNCI', width=500, height=300)
# https://youtu.be/Kd4BGDpSNCI

# %% [markdown]
# Dataset : https://www.kaggle.com/c/rossmann-store-sales/data
#
#
#
# * Id - an Id that represents a (Store, Date) duple within the test set
# * Store - a unique Id for each store
# * Sales - the turnover for any given day (this is what you are predicting)
# * Customers - the number of customers on a given day
# * Open - an indicator for whether the store was open: 0 = closed, 1 = open
# * StateHoliday - indicates a state holiday. Normally all stores, with few exceptions, are closed on state holidays. Note that all schools are closed on public holidays and weekends. a = public holiday, b = Easter holiday, c = Christmas, 0 = None
# * SchoolHoliday - indicates if the (Store, Date) was affected by the closure of public schools
# * StoreType - differentiates between 4 different store models: a, b, c, d
# * Assortment - describes an assortment level: a = basic, b = extra, c = extended
# * CompetitionDistance - distance in meters to the nearest competitor store
# * CompetitionOpenSince[Month/Year] - gives the approximate year and month of the time the nearest competitor was opened
# * Promo - indicates whether a store is running a promo on that day
# * Promo2 - Promo2 is a continuing and consecutive promotion for some stores: 0 = store is not participating, 1 = store is participating
# * Promo2Since[Year/Week] - describes the year and calendar week when the store started participating in Promo2
# * PromoInterval - describes the consecutive intervals Promo2 is started, naming the months the promotion is started anew. E.g. "Feb,May,Aug,Nov" means each round starts in February, May, August, November of any given year for that store

# %%
sales_data=pd.read_csv("https://raw.githubusercontent.com/venkatareddykonasani/Datasets/master/Rossmann_Store_Sales/Rossmann_Store_Sales.zip", compression="zip")
print(sales_data.shape)
print(sales_data.info())
sales_data.sample(5)

# %%
#Sales
plt.boxplot(sales_data["Sales"])
plt.show()
sns.violinplot(y=sales_data["Sales"])
plt.show()
sns.distplot(sales_data["Sales"])
plt.show()
sns.distplot(sales_data["Sales"],kde=False)
plt.show()

# %%
# Customers 
plt.boxplot(sales_data["Customers"])
plt.show()
sns.violinplot(y=sales_data["Customers"])
plt.show()
sns.distplot(sales_data["Customers"])
plt.show()
sns.distplot(sales_data["Customers"],kde=False)
plt.show()

# %% [markdown]
# # Categorical Variables Summary

# %%
YouTubeVideo('UdJ825qJh0o', width=500, height=300)
# https://youtu.be/UdJ825qJh0o

# %% [markdown]
# ## Bar Charts

# %%
plt.figure()
sns.countplot(x="job",  data=bank_data)

# %%
plt.figure()
sns.countplot(y="job",  data=bank_data)

# %%
categorical_cols=[col for col in bank_data.columns if bank_data[col].dtypes in ["object"]]
print(categorical_cols)

# %%
plt.figure()
for col in categorical_cols:
  sns.countplot(y=col,  data=bank_data)
  plt.title([col + " Bar plot"])
  plt.show()

# %% [markdown]
# # Rossmann Store Sales

# %%
sns.countplot("StoreType",  data=sales_data)

# %%
sns.countplot("Assortment",  data=sales_data)

# %% [markdown]
# # Continuous vs Continuous

# %%
YouTubeVideo('SsH9dQfkojg', width=500, height=300)
# https://youtu.be/SsH9dQfkojg

# %% [markdown]
# ## Scatter Plots

# %%
bank_data.columns

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x="age", y="balance", data=bank_data)

# %%
sns.scatterplot(x="age", y="balance", hue="y", data=bank_data)

# %%
sns.scatterplot(x="age", y="balance", hue="y", data=bank_data[bank_data["balance"]<20000])

# %% [markdown]
# # Rossmann Store Sales

# %%
#Sales vs Customers
sns.scatterplot(y="Sales", x="Customers", data=sales_data)

# %%
#Sales vs CompetitionDistance 
sns.scatterplot(y="Sales", x="CompetitionDistance", data=sales_data)

# %% [markdown]
# # Continuous vs Categorical

# %%
YouTubeVideo('kfuNWhO3t2c', width=500, height=300)
# https://youtu.be/kfuNWhO3t2c

# %% [markdown]
# ## Histogram overlay

# %%
sns.distplot(bank_data[bank_data["y"]=="no"]["age"], color="red")
sns.distplot(bank_data[bank_data["y"]=="yes"]["age"], color="green")

# %%
plt.figure()
for col in numeric_cols:
  sns.distplot(bank_data[bank_data["y"]=="no"][col], color="red")
  sns.distplot(bank_data[bank_data["y"]=="yes"][col], color="green")
  plt.title([col + " Histogram"])
  plt.show()

# %% [markdown]
# ## Box Plots for Continuous and Categories comparison

# %%
sns.boxplot( x=bank_data["y"], y=bank_data["age"])
plt.title('Age vs y', fontsize=20)

# %%
numeric_cols=[col for col in bank_data.columns if bank_data[col].dtypes in ["int64","float64"]]
print(numeric_cols)

for col in numeric_cols:
  sns.boxplot( x=bank_data["y"], y=bank_data[col])
  plt.title([col, "vs y"], fontsize=20)
  plt.show()

# %% [markdown]
# ## Violin plots for Continuous and Categories comparison

# %%
sns.violinplot( x=bank_data["y"], y=bank_data["age"])
plt.title('Age vs y', fontsize=20)

# %%
numeric_cols=[col for col in bank_data.columns if bank_data[col].dtypes in ["int64","float64"]]
print(numeric_cols)

for col in numeric_cols:
  sns.violinplot( x=bank_data["y"], y=bank_data[col])
  plt.title([col, "vs y"], fontsize=20)
  plt.show()

# %% [markdown]
# # Rossmann Store Sales

# %%
#Sales vs Promotion
sns.distplot(sales_data[sales_data["Promo"]==1]["Sales"], color="red")
sns.distplot(sales_data[sales_data["Promo"]==0]["Sales"], color="green")
plt.show()
sns.boxplot(x=sales_data["Promo"], y=sales_data["Sales"])
plt.show()
sns.violinplot(x=sales_data["Promo"], y=sales_data["Sales"])
plt.show()

# %%
#Sales vs StateHoliday
sns.distplot(sales_data[sales_data["StateHoliday"]!=0]["Sales"], color="red")
sns.distplot(sales_data[sales_data["StateHoliday"]==0]["Sales"], color="green")
plt.show()
sns.boxplot(x=sales_data["StateHoliday"]==0, y=sales_data["Sales"])
plt.show()
sns.violinplot(x=sales_data["StateHoliday"]==0, y=sales_data["Sales"])
plt.show()

# %%
#Sales vs DayOfWeek
sns.boxplot(x=sales_data["DayOfWeek"], y=sales_data["Sales"])
plt.show()

# %% [markdown]
# # Categorical vs Categorical

# %%
YouTubeVideo('t8EdINaQrzs', width=500, height=300)
# https://youtu.be/t8EdINaQrzs

# %% [markdown]
# ## Bar Chart for categorical variable comparison

# %%
sns.countplot(y="education",  data=bank_data[bank_data["y"]=="no"], color="red")
sns.countplot(y="education",  data=bank_data[bank_data["y"]=="yes"], color="green")

# %%
plt.figure()
for col in categorical_cols:
  sns.countplot(y=col,  data=bank_data[bank_data["y"]=="no"], color="red")
  sns.countplot(y=col,  data=bank_data[bank_data["y"]=="yes"], color="green")
  plt.title([col + " Bar plot"])
  plt.show()

# %%
plt.figure()
for col in categorical_cols:
  sns.countplot(y=col,  data=bank_data,hue="y")
  plt.title([col + " Bar plot"])
  plt.show()

# %% [markdown]
# ## Cross Tables

# %%
for col in categorical_cols:
  print(pd.crosstab(bank_data[col], bank_data['y']))

# %%
for col in categorical_cols:
  print(pd.crosstab(bank_data[col], bank_data['y'], margins=True))
  print("============================\n")

# %% [markdown]
# # Rossmann Store Sales

# %%
sns.countplot(y="DayOfWeek",  data=sales_data, hue="Promo")

# %%
print(pd.crosstab(sales_data["DayOfWeek"], sales_data['Promo']))
pd.crosstab(sales_data["DayOfWeek"], sales_data['Promo']).apply(lambda x: x/x.sum(), axis=1)

# %% [markdown]
# # Pivot table visualization

# %% [markdown]
# ## Heat maps

# %%
pivot=pd.pivot_table(bank_data,values='balance', index=['job'], columns='y')
print(pivot)
sns.heatmap(pivot)

# %%
pivot=pd.pivot_table(bank_data,values='balance', index=['job'], columns='y')
sns.heatmap(pivot, cmap="YlGnBu")

# %% [markdown]
# ## Groupby

# %%
bank_data.groupby("y")['balance'].mean()

# %%
for col in numeric_cols:
  print(bank_data.groupby("y")[col].mean())
  print("============================\n")

# %% [markdown]
# # Rossmann Store Sales

# %%
sales_data.groupby("Promo")['Sales'].mean()

# %%
sales_data.groupby("DayOfWeek")['Sales'].mean()

# %%
pivot=pd.pivot_table(sales_data,values='Sales', index=['DayOfWeek'], columns='Promo')
print(pivot)
sns.heatmap(pivot, cmap="Oranges")

# %%
#'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 
#'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 
#'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 
#'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spe...

# %% [markdown]
# # Conclusion

# %%
YouTubeVideo('q4bmWY33iKg', width=500, height=300)
# https://youtu.be/q4bmWY33iKg

# %% [markdown]
# ---
# ---
# # Useful Links and Details

# %% [markdown]
# ### Next Session Link
# [Session-4 : Data Cleaning](https://colab.research.google.com/drive/1l8vsQWxoAvFvY9wb8HEJX_GfLKd-pF8e?usp=sharing)

# %% [markdown]
# ### Previous Session Link
# [
# Session-3.1 : Basic Statistics ](https://colab.research.google.com/drive/15RG9irOwj_C4ktebSk4_hqdox2_nxoln#scrollTo=9i9w3aYDq3yc)

# %% [markdown]
# ### Our Full Course Details
#
# [Enrol Now](https://statinfer.com/course/machine-learning-with-python-course-in-india/)

# %%
YouTubeVideo('v8WvvX5DZi0', width=500, height=300)
# https://youtu.be/v8WvvX5DZi0

# %% [markdown]
# [Enrol Now](https://statinfer.com/course/machine-learning-with-python-course-in-india/)
